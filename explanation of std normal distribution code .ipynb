# %%
import pandas as pd
#import pandas for dataset identification

# %%
dataset=pd.read_csv("preplacementdata.csv")
#datset after  datapreprocessing

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
def stdNBgraph(dataset):
    #to creat a functio of  standard normal distributin graph from dataset of specific column
    #to convert normal distribution to standard normal distribution 
    import seaborn as sns
    #load seaborn for shown graph of stdNB
    mean=dataset.mean()
    #to calculate mean of specific column ssc_p
    std=dataset.std()
    #to calculate std of ssc_p
    values=[i for i in dataset] 
    #values for specific column of ssc_p  to convert list
    z_score=[((j-mean)/std) for j in values]
    #to calculate z_score by z_score fromula with for loop  [ x value of ssc_p is subtract to mean value of ssc_p and divided into std of ssc_p]
    sns.distplot(z_score,kde=True)
    #to show the graph of standed normal distribution of respected column of dataset by calculated z_score value with sns distplot
    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["ssc_p"])
#call function of std nbgraph of dataset with  respected column name
# Out:
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   del sys.path[0]

# %%
#above shown graph tells the only x value change witout change distribution curve
